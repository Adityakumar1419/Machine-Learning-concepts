# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
webpage
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;57722c31&#46;1760518863&#46;1637c4bc\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;57722c31&#46;1760518863&#46;1637c4bc</P>\n</BODY>\n</HTML>\n'

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.ambitionbox.com/list-of-companies?" on this server.
#   <p>
#    Reference #18.57722c31.1760518863.1637c4bc
#   </p>
#   <p>
#    https://errors.edgesuite.net/18.57722c31.1760518863.1637c4bc
#   </p>
#  </body>
# </html>

# %%
soup.find_all('h1')[0].text
# Out:
# 'Access Denied'

# %%
df= pd.read_csv('Titanic-Dataset.csv')

# %%
# EDA

# %%
import pandas as pd
import seaborn as sns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ANALYSIS OF NUMERICAL COLUMNS

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=50)
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 27., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_23704\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
df = pd.read_csv('EPe BA intern assesment Raw data - Sheet1.csv')

# %%
df
# Out:
#     Lead ID     Store Name Lead Type   Lead Date Pre-Booking Date  \
# 0     L1000  Bangalore MBC      Warm  2025-10-21       2025-10-25
# 1     L1001      Delhi MBC      Warm  2025-10-11       2025-10-14
# 2     L1002     Mumbai MBC      Cold  2025-10-01              NaN
# 3     L1003  Bangalore MBC      Cold  2025-10-28              NaN
# 4     L1004      Delhi MBC      Warm  2025-10-14       2025-10-18
# ..      ...            ...       ...         ...              ...
# 995   L1995    Chennai MBC       Hot  2025-10-07       2025-10-10
# 996   L1996     Mumbai MBC       Hot  2025-10-14       2025-10-19
# 997   L1997  Bangalore MBC      Warm  2025-10-15       2025-10-20
# 998   L1998  Bangalore MBC      Cold  2025-10-29              NaN
# 999   L1999     Mumbai MBC      Warm  2025-10-08       2025-10-13
#
#     Booking Date Delivery Date Cancellation Status Cancellation Reason  \
# 0     2025-10-29    2025-11-03                  No                 NaN
# 1     2025-10-19    2025-10-26                  No                 NaN
# 2            NaN           NaN                 Yes               Other
# 3            NaN           NaN                 Yes   Model Unavailable
# 4     2025-10-21    2025-10-24                  No                 NaN
# ..           ...           ...                 ...                 ...
# 995   2025-10-15    2025-10-21                  No                 NaN
# 996   2025-10-23    2025-10-26                  No                 NaN
# 997   2025-10-24    2025-10-30                  No                 NaN
# 998          NaN           NaN                 Yes        Changed Mind
# 999   2025-10-15    2025-10-18                  No                 NaN
#
#     Service Follow-up Date  TAT Pre-Booking (Days)  TAT Booking (Days)  \
# 0               2025-11-28                     4.0                 4.0
# 1               2025-11-22                     3.0                 5.0
# 2                      NaN                     NaN                 NaN
# 3                      NaN                     NaN                 NaN
# 4               2025-11-12                     4.0                 3.0
# ..                     ...                     ...                 ...
# 995             2025-11-18                     3.0                 5.0
# 996             2025-11-12                     5.0                 4.0
# 997             2025-11-19                     5.0                 4.0
# 998                    NaN                     NaN                 NaN
# 999             2025-11-13                     5.0                 2.0
#
#      TAT Delivery (Days)  Customer Rating
# 0                    5.0              2.0
# 1                    7.0              8.0
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    3.0              8.0
# ..                   ...              ...
# 995                  6.0              5.0
# 996                  3.0              7.0
# 997                  6.0              3.0
# 998                  NaN              NaN
# 999                  3.0              4.0
#
# [1000 rows x 14 columns]
